# %% [markdown]
# # **Project Name**    -Mental Health Survey EDA Analysis

# %% [markdown]
# ##### **Contribution By**
# ##### ANBARASU A

# %% [markdown]
# # **Project Summary -**
# This project explores the results of a 2014 survey examining attitudes toward mental health and the prevalence of mental health disorders in the tech industry. The dataset, sourced from Open Sourcing Mental Illness (OSMI), includes self-reported responses from individuals working in tech-related roles worldwide.

# %% [markdown]
# # **GitHub Link -** https://github.com/Anbhu11/Mental-Health-Survey-EDA-Analysis

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Dataset Loading &  Dataset First View

# %%
df=pd.read_csv(r"C:\Users\anbub\OneDrive\Desktop\mental health survey\Mental Health Survey EDA Analysis\survey.csv")
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
df.shape
# Out:
# (1259, 27)

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Timestamp                    object
# Age                           int64
# Gender                       object
# Country                      object
# state                        object
# self_employed                object
# family_history               object
# treatment                    object
# work_interfere               object
# no_employees                 object
# remote_work                  object
# tech_company                 object
# benefits                     object
# care_options                 object
# wellness_program             object
# seek_help                    object
# anonymity                    object
# leave                        object
# mental_health_consequence    object
# phys_health_consequence      object
# coworkers                    object
# supervisor                   object
# mental_health_interview      object
# phys_health_interview        object
# mental_vs_physical           object
# obs_consequence              object
# ...

# %% [markdown]
# ### Dataset Information

# %%
df.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %%
df.nunique()
# Out:
# Timestamp                    1246
# Age                            53
# Gender                         49
# Country                        48
# state                          45
# self_employed                   2
# family_history                  2
# treatment                       2
# work_interfere                  4
# no_employees                    6
# remote_work                     2
# tech_company                    2
# benefits                        3
# care_options                    3
# wellness_program                3
# seek_help                       3
# anonymity                       3
# leave                           5
# mental_health_consequence       3
# phys_health_consequence         3
# coworkers                       3
# supervisor                      3
# mental_health_interview         3
# phys_health_interview           3
# mental_vs_physical              3
# obs_consequence                 2
# comments                      160
# dtype: int64

# %%
df.describe(include=[object])     # for strings
# Out:
#                   Timestamp Gender        Country state self_employed  \
# count                  1259   1259           1259   744          1241
# unique                 1246     49             48    45             2
# top     2014-08-27 12:44:51   Male  United States    CA            No
# freq                      2    615            751   138          1095
#
#        family_history treatment work_interfere no_employees remote_work  ...  \
# count            1259      1259            995         1259        1259  ...
# unique              2         2              4            6           2  ...
# top                No       Yes      Sometimes         6-25          No  ...
# freq              767       637            465          290         883  ...
#
#              leave mental_health_consequence phys_health_consequence  \
# count         1259                      1259                    1259
# unique           5                         3                       3
# ...

# %%
df.rename(columns={'self_employed': 'Self_Employed',
       'family_history':'Family_History','treatment':'Treatment','work_interfere':'Work_Interfere','no_employees':'No_Employees',
       'remote_work':'Remote_Work','tech_company':'Tech_Company','benefits':'Benefits','care_options':'Care_Options',
       'wellness_program':'Wellness_Program','seek_help':'Seek_Help','anonymity':'Anonymity','leave':'Leave',
       'mental_health_consequence':'Mental_Health_Consequence','phys_health_consequence':'Phys_Health_Consequence','coworkers':'Coworkers',
       'supervisor':'Supervisor','mental_health_interview':'Mental_Health_Interview','phys_health_interview':'Phys_Health_Interview',
       'mental_vs_physical':'Mental_vs_Physical','obs_consequence':'Obs_Consequence','comments':'Comments'})
# Out:
#                 Timestamp  Age  Gender         Country state Self_Employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      Family_History Treatment Work_Interfere    No_Employees  ...  \
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isna().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %% [markdown]
# #### Duplicate Values

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Gender, Country, state, self_employed, family_history, treatment, work_interfere, no_employees, remote_work, tech_company, benefits, care_options, wellness_program, seek_help, anonymity, leave, mental_health_consequence, phys_health_consequence, coworkers, supervisor, mental_health_interview, phys_health_interview, mental_vs_physical, obs_consequence, comments]
# Index: []
#
# [0 rows x 27 columns]

# %%
df.loc[df.duplicated(subset=['self_employed'])].head(50)
# Out:
#               Timestamp  Age  Gender         Country state self_employed  \
# 1   2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2   2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3   2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4   2014-08-27 11:30:22   31    Male   United States    TX           NaN
# 5   2014-08-27 11:31:22   33    Male   United States    TN           NaN
# 6   2014-08-27 11:31:50   35  Female   United States    MI           NaN
# 7   2014-08-27 11:32:05   39       M          Canada   NaN           NaN
# 8   2014-08-27 11:32:39   42  Female   United States    IL           NaN
# 9   2014-08-27 11:32:43   23    Male          Canada   NaN           NaN
# 10  2014-08-27 11:32:44   31    Male   United States    OH           NaN
# 11  2014-08-27 11:32:49   29    male        Bulgaria   NaN           NaN
# 12  2014-08-27 11:33:23   42  female   United States    CA           NaN
# ...

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Gender, Country, state, self_employed, family_history, treatment, work_interfere, no_employees, remote_work, tech_company, benefits, care_options, wellness_program, seek_help, anonymity, leave, mental_health_consequence, phys_health_consequence, coworkers, supervisor, mental_health_interview, phys_health_interview, mental_vs_physical, obs_consequence, comments]
# Index: []
#
# [0 rows x 27 columns]

# %%
df
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %% [markdown]
# ## Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables

# %% [markdown]
# #### Chart - 1

# %%
ax=df['Age'].value_counts().head(10).plot(kind='hist',title='Age of customers')
ax.set_xlabel('Age')
ax.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# #### Chart - 2

# %%
ax=df['Country'].value_counts().plot(kind='bar')
ax.set_xlabel('Country')
ax.set_ylabel('count')
# Out:
# Text(24.000000000000007, 0.5, 'count')

# %% [markdown]
# #### Chart - 3

# %%
ax=df['Gender'].value_counts().plot(kind='bar')
ax.set_xlabel('Gender')
ax.set_ylabel('count')
# Out:
# Text(24.000000000000007, 0.5, 'count')

# %% [markdown]
# #### Chart - 4

# %%
df['no_employees'].value_counts().plot(kind='pie',title='NO Of Employees')
# Out:
# <Axes: title={'center': 'NO Of Employees'}, ylabel='count'>

# %% [markdown]
# #### Chart - 5

# %%
ax=df['work_interfere'].value_counts().plot(kind='bar')
ax.set_xlabel('work_interfere')
ax.set_ylabel('count')
# Out:
# Text(24.000000000000007, 0.5, 'count')

# %%
ax=df['state'].value_counts().plot(kind='bar')
ax.set_xlabel('state')
ax.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ## Solution to Business Objective
# 1.Enhance Employer-Provided Mental Health Benefits
# 2.Reduce Mental Health Stigma Through Awareness Campaigns
# 3.Train Managers to Handle Mental Health Conversations
# 4.Introduce or Improve Wellness Programs
# 5.Use Data to Drive Improvements

# %% [markdown]
# # Conclusion
# The analysis of the Mental Health in Tech Survey highlights a pressing need for better mental health awareness, support, and inclusion within the tech industry. While many employees experience mental health challenges, stigma, lack of resources, and organizational silence often prevent them from seeking help.
#
# Key findings reveal that:
#
# A significant portion of respondents have experienced mental health issues, yet not all have sought treatment.
# Many employees are unsure whether their employers provide mental health benefits or resources.
# There is a clear gap in comfort levels when discussing mental health with coworkers versus supervisors.
# Perceived negative consequences of disclosure still exist, especially in the workplace.
# To foster a healthier work environment, tech companies must take proactive steps—such as improving mental health policies, training leaders, encouraging open conversations, and ensuring accessible support for both in-office and remote employees.
# Ultimately, promoting mental wellness is not just a moral imperative—it’s a strategic advantage for attracting, retaining, and empowering talent in a demanding industry.
